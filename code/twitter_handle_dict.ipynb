# %%
twitter_handles = {
'1HiveLLC' : '1HiveOrg', 
'1inch' : '1inch',
'1UP': '1UP',
'Aave': 'AaveAave',
'Aavegotchi': 'aavegotchi',
'AGAH DAO': 'itstheAGAH',
'Airalab': 'AIRA_Robonomics',
'AirSwap': 'airswap',
'AladdinDAO': 'aladdindao',
'Alchemist': 'AlchemistDAO',
'Alchemix': 'AlchemixFi',
'Ampleforth': 'AmpleforthOrg',
'APE DAO': 'ApeDao_',
'API3': 'API3DAO',
'Aragon': 'AragonDao',
'Aragon One':'AragonOneTeam',
'Arca': 'ARCA_DAO',
'Armor':'ArmorFi',
'array.finance CCO': 'arrayfinance',
'B.Protocol': 'bprotocoleth',
'BaconDAO': 'BaconDAO_',
'Badger': 'BadgerDAO',
'Balancer': 'BalancerLabs',
'Bancor': 'bancor',
'Bankless DAO': 'banklessDAO',
'BarnBridge': 'Barn_Bridge',
'BitDAO':'@BitDAO_Official',
'Blockzero Labs': 'blockzerolabs',
'BrightID': 'BrightIDProject',
'Buzzed Bear Hideout': 'BuzzedBears',
'bZx': 'bzxhq',
'Carbonswap':'carbonswap_fi',
'CENNZnet Grants DAO': 'CENNZnet',
'CityDAO': 'CityDAO',
'Collab19': 'collab_19',
'collectiveDAO':'collectiveDAO', 
'Compound': 'compoundfinance',
'Conjure':'ConjureFi',
'Constitution': 'ConstitutionDAO',
'Convex Finance':'ConvexFinance',
'CRE8RDAO': 'CRE8RDAO',
'Cream Finance': 'creamfinance',
'Credmark': 'credmarkhq',
'CrisisDAO': 'crisisdao',
'Cryptex': 'CryptexFinance',
'CryptoCorgis': 'CorgisCrypto',
'Cura Dao': 'Cura_DAO',
'Curio': 'curio_invest',
'Cyber Congress': 'cyber_devs',
'DAOhaus Second Story CCO':'nowdaoit',
'DAOSquare':'DAOSquare',
'Decentraland':'decentraland',
'Decred': 'DecredAustralia',
'DeFi Omega': 'DeFiOmega',
'DefiDollar DAO': 'defidollar',
'Developer DAO': 'developer_dao',
'dHEDGE':'dHedgeOrg',
'Diamond Bank':'diamondbankdao',
'Digital Reserve Currency': 'drctoken',
'Doodles': 'doodledaonfts',
'dOrg': 'dOrg_tech',
'Dtravel': 'DtravelDAO',
'DXdao': 'DXdao_',
'dYdX': 'dydxprotocol',
'DynamicSetDollar': 'dsdproject',
'Earthfund': 'EarthFund_io',
'EmptySetDollar': 'emptysetdollar',
'Enzyme Finance': 'enzymefinance',
'Ethereum Name Service': 'ensdomains',
'EulerBeats OG DAO': 'eulerbeats',
'Farmgod DAO': 'farmgoddao',
'Fei Money': 'feiprotocol',
'Finance.Vote': 'financedotvote',
'Fingerprints DAO': 'FingerprintsDAO',
'flamingo': 'FLAMINGODAO',
'Forefront': 'forefront__',
'Fraktal DAO': 'FraktalNFT',
'Friends With Benefits': 'FWBtweets',
'Frontier': 'FrontierDAO',
'Game Mine Alliance': 'G_M_Alliance',
'GCR DAO': 'Globalcoinrsrch',
'Gitcoin': 'gitcoin',
'Gnosis': 'gnosisPM',
'GoodDollar': 'gooddollarorg',
'Governor DAO': 'Governor_DAO',
'Hakt DAO': 'HaktDAO',
'HausDAO': 'nowdaoit',
'HoneyDAO': 'honeydao_',
'Idle': 'idlefinance',
'Index': 'Index_DAO',
'Index Coop': 'indexcoop',
'Indexed': 'ndxfi',
'Instadapp': 'Instadapp',
'Inverse Finance': 'InverseFinance',
'JammSession': 'JammSession_',
'Jenny Metaverse DAO': 'JennyMetaverse',
'JuiceboxDAO': 'juiceboxeth',
'Keep2r': 'kp2rnetwork',
'Keeper DAO': 'Keeper_DAO',
'Kleros': 'Kleros_io',
'Klima DAO': 'KlimaDAO',
'Komorebi Collective': 'KomorebiFund',
'Krause House': 'KrauseHouseDAO',
'Kusama': 'kusamanetwork',
'LexDAO': 'lex_DAO',
'Lido': 'LidoFinance',
'Machi X DAO': 'MachiXOfficial',
'Maker Dao': 'MakerDao',
'MantraDAO': 'MANTRADAO',
'Markeing DAO': 'MarketingDAO',
'MarsDao': 'TheMarsDao',
'MeebitsDAO': 'MeebitsDAO',
'Meta Gamma Delta': 'metagammadelta',
'MetaCartel DAO': 'Meta_Cartel',
'MetaCartel Ventures': 'VENTURE_DAO',
'MetaCartel Ventures China': 'VentureDAOChina',
'MetaClan': 'MetaClan',
'MetaFactory': 'TheMetaFactory',
'Metafam': 'MetaFam',
'Meter Governance MTRG': 'Meter_IO',
'Moloch DAO': 'MolochDAO',
'mStable': 'mstable_',
'MyDaoDashboard': 'mydaodashboard',
'necDAO': 'necdao',
'Neptune DAO': 'neptuneda0',
'NFTX': 'NFTX_',
'Nouns DAO': 'nounsdao',
'OceanDAO': 'OceanDAO_',
'OlympusDAO': 'OlympusDAO',
'OOKI':'OokiTrade',
'OpenDAO': 'The_OpenDAO',
'Orochi DAO V2': 'orochidao',
'Overstimulated DAO': 'imdanielallan',
'Own.fund DAO': 'Own_fund',
'PancakeSwap': 'PancakeSwap',
'Pangolin': 'pangolindex',
'PartyDAO': 'prtyDAO',
'PastaDAOv0': 'Pasta_DAO',
'PegzDAO': 'pegzdao',
'Perpetual Protocol': 'perpprotocol',
'Pickle Finance': 'picklefinance',
'PieDAO': 'PieDAO_DeFi',
'PleasrDAO': 'PleasrDAO',
'pNetwork': 'pNetworkDeFi',
'PoolTogether': 'PoolTogether_',
'Powerpool': 'powerpoolcvp',
'Premia': 'PremiaFinance',
'PrimeDAO': 'PrimeDAO_',
'Proof of Humanity': 'proofofhumanity',
'Radicle': 'radicle',
'Raid Guild': 'RaidGuild',
'Rally': 'rally_io',
'RaribleDAO': 'raribleprotocol',
'RariCapital': 'RariCapital',
'REtoken DAO': 'REtokenDAO',
'Ribbon': 'ribbonfinance',
'Rocket LP DAO': 'rocketdao_io',
'Seedify.fund': 'SeedifyFund',
'seen.haus': 'seen_haus',
'ShapeShift': 'ShapeShift_io',
'Shark DAO':'sharkdao',
'ShieldDao': 'shield_dao',
'ShillShop': 'RGShillShop',
'snglsDAO': 'snglsDAO',
'SquiggleDAO': 'squiggledao',
'Stacker Ventures': 'StackerVentures',
'STAKEhaus': 'STAKEhaus',
'StakeWise': 'stakewise_io',
'Status': 'ethstatus',
'Sushiswap': 'sushiswap',
'Synthetix': 'synthetix_io',
'TeaSwap': 'SwapTea',
'The LAO': 'TheLAOOfficial',
'TheGraph': 'graphprotocol',
'Token Engineering Commons': 'tecmns',
'Tokenlon': 'tokenlon',
'Tornado Cash': 'TornadoCash',
'Tracer': 'TracerDAO',
'TrojanDAO': 'TrojanDAO',
'TrueFi': 'TrustToken',
'TYAN Intergalactic': 'dao_tyan',
'UberHAUS': 'uber_haus',
'UltraDAO V2': 'Ultra_DAO',
'Unicly': 'uniclyNFT',
'Uniswap': 'Uniswap',
'Unslashed': 'UnslashedF',
'Varen': 'varenfinance',
'Vesper': 'VesperFi',
'Visor': 'VisorFinance',
'VitaDAO': 'vita_dao',
'WGMI': 'wgmi4thepeople',
'XDAO': 'xdaoapp',
'Yam Finance': 'YamFinance',
'Yearn Finance': 'iearnfinance',
'yfBeta': 'yfBeta',
'Yup': 'yup_io'
}

# %%
import pandas as pd

# %%
handles = pd.DataFrame(twitter_handles.items(), columns=['name', 'twitter_handle'])

# %%
handles['twitter_url'] = ('https://twitter.com/'+handles['twitter_handle'])

# %%
handles.to_csv('twitter_handles.csv', index = False)
